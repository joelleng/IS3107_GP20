# %%
import pandas as pd

# %%
df = pd.read_csv('processed_used_cars.csv')

# %%
df.iloc[:,:16]
# Out:
#          price  depreciation_per_year  coe_left  mileage  manufactured_year  \
# 0     450000.0                52920.0      3099    69200               2003
# 1     888000.0               102380.0      3159    29000               2003
# 2     108888.0                13190.0      3010   135000               2003
# 3     180800.0                20080.0      3277    46000               2004
# 4     450000.0                48050.0      3414    64700               2004
# ...        ...                    ...       ...      ...                ...
# 8999  345800.0                31390.0      3581       10               2025
# 9000  155800.0                14840.0      3636       55               2025
# 9001  144888.0                14020.0      3564       50               2025
# 9002  142888.0                13360.0      3589       90               2025
# 9003  249999.0                23210.0      3587     2500               2025
#
# ...
